# %%
# read data
import pandas as pd
import numpy as np
from IPython.display import clear_output
results = pd.read_csv('results.csv', encoding= 'unicode_escape')

# %%
results[results.Season == '2008-09']
# Out:
#        Season              DateTime       HomeTeam       AwayTeam  FTHG  FTAG  \
# 5864  2008-09  2008-08-16T00:00:00Z        Arsenal      West Brom     1     0
# 5865  2008-09  2008-08-16T00:00:00Z         Bolton          Stoke     3     1
# 5866  2008-09  2008-08-16T00:00:00Z        Everton      Blackburn     2     3
# 5867  2008-09  2008-08-16T00:00:00Z           Hull         Fulham     2     1
# 5868  2008-09  2008-08-16T00:00:00Z  Middlesbrough      Tottenham     2     1
# ...       ...                   ...            ...            ...   ...   ...
# 6239  2008-09  2009-05-24T00:00:00Z      Liverpool      Tottenham     3     1
# 6240  2008-09  2009-05-24T00:00:00Z       Man City         Bolton     1     0
# 6241  2008-09  2009-05-24T00:00:00Z     Sunderland        Chelsea     2     3
# 6242  2008-09  2009-05-24T00:00:00Z       West Ham  Middlesbrough     2     1
# 6243  2008-09  2009-05-24T00:00:00Z          Wigan     Portsmouth     1     0
#
#      FTR  HTHG  HTAG HTR  ...   HST   AST    HC   AC    HF    AF   HY   AY  \
# 5864   H   1.0   0.0   H  ...  14.0   4.0   7.0  5.0  11.0   8.0  0.0  0.0
# 5865   H   3.0   0.0   H  ...   8.0   2.0   4.0  3.0  13.0  12.0  1.0  2.0
# 5866   A   1.0   1.0   D  ...   5.0  11.0   3.0  5.0  11.0   9.0  2.0  2.0
# 5867   H   1.0   1.0   D  ...   6.0   6.0   5.0  6.0  10.0   9.0  3.0  0.0
# 5868   H   0.0   0.0   D  ...  10.0   5.0   7.0  9.0  11.0  12.0  1.0  2.0
# ...   ..   ...   ...  ..  ...   ...   ...   ...  ...   ...   ...  ...  ...
# 6239   H   1.0   0.0   H  ...   9.0   4.0   9.0  2.0  14.0   4.0  0.0  1.0
# 6240   H   1.0   0.0   H  ...  12.0   4.0  15.0  9.0   8.0  10.0  0.0  0.0
# 6241   A   0.0   0.0   D  ...   7.0   9.0   6.0  7.0   8.0   7.0  1.0  1.0
# 6242   H   1.0   0.0   H  ...   8.0   6.0   4.0  5.0  14.0  10.0  0.0  1.0
# 6243   H   1.0   0.0   H  ...  10.0   3.0   8.0  2.0   8.0  21.0  0.0  4.0
#
#        HR   AR
# 5864  0.0  0.0
# 5865  0.0  0.0
# 5866  0.0  0.0
# 5867  0.0  0.0
# 5868  0.0  0.0
# ...   ...  ...
# 6239  0.0  0.0
# 6240  0.0  0.0
# 6241  0.0  0.0
# 6242  0.0  0.0
# 6243  0.0  0.0
#
# [380 rows x 23 columns]

# %%
start = '2010-11'
average_by = 10
weights = [1] * average_by
useless_heads = ['Season', 'DateTime', 'HomeTeam', 'AwayTeam', 'FTR', 'HTR', 'Referee']

# %%
def generate_heads():
    heads = np.array(results.columns)
    good_heads = [i for i in heads if i not in useless_heads]
    a_heads = ["a_" + i for i in good_heads]
    b_heads = ["b_" + i for i in good_heads]
    heads = a_heads+b_heads
    heads

# %%
def calculate_means(team_name, label, average_by, index):
    heads = np.array(results.columns)
    good_heads = [i for i in heads if i not in useless_heads]
    res = np.array([0] * len(good_heads))
    cnt = 0
    for index, row in results.loc[index-1:0:-1].iterrows():
        if label == 'A':
            if row['AwayTeam'] == team_name:
                res = res + row[good_heads].to_numpy()
                cnt += 1
        elif label == 'H':
            if row['HomeTeam'] == team_name:
                res = res + row[good_heads].to_numpy()
                cnt += 1
        if cnt == average_by:
            break
    if cnt != average_by:
        return [np.nan] * len(good_heads)
    res /= average_by
    return res

# %%
def process_data(start, average_by, weights):
    X = pd.DataFrame(columns = generate_heads())
    y = np.array([])
    begin = results[results.Season == start].index[0]
    for index, row in results.loc[begin:].iterrows():
        a_row = calculate_means(row['HomeTeam'], 'H', average_by, index)
        b_row = calculate_means(row['AwayTeam'], 'A', average_by, index)
        new_row = np.append(a_row, b_row)
        z = pd.DataFrame(zip(X.columns, list(new_row)))
        X = X.append(z, ignore_index=1)
        y = np.append(y, row['FTR'])
        print(index - begin, "/", results.shape[0] - begin)
        clear_output(wait=True)
    return X, y

# %%
X, y = process_data(start, average_by, weights)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-958f64064c30> in <module>
# ----> 1 X, y = process_data(start, average_by, weights)
#
# <ipython-input-6-9f0bef4768f2> in process_data(start, average_by, weights)
#       4     begin = results[results.Season == start].index[0]
#       5     for index, row in results.loc[begin:].iterrows():
# ----> 6         a_row = calculate_means(row['HomeTeam'], 'H', average_by, index)
#       7         b_row = calculate_means(row['AwayTeam'], 'A', average_by, index)
#       8         new_row = np.append(a_row, b_row)
#
# <ipython-input-5-499a69030f2c> in calculate_means(team_name, label, average_by, index)
#       4     res = np.array([0] * len(good_heads))
#       5     cnt = 0
# ----> 6     for index, row in results.loc[index-1:0:-1].iterrows():
#       7         if label == 'A':
#       8             if row['AwayTeam'] == team_name:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in iterrows(self)
#    1012         klass = self._constructor_sliced
#    1013         for k, v in zip(self.index, self.values):
# -> 1014             s = klass(v, index=columns, name=k)
#    1015             yield k, s
#    1016
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     327                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     328
# --> 329                 data = SingleBlockManager.from_array(data, index)
#     330
#     331         generic.NDFrame.__init__(self, data)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in from_array(cls, array, index)
#    1576         Constructor for if we have an array that is not yet a Block.
#    1577         """
# -> 1578         block = make_block(array, placement=slice(0, len(index)), ndim=1)
#    1579         return cls(block, index)
#    1580
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2735     if klass is None:
#    2736         dtype = dtype or values.dtype
# -> 2737         klass = get_block_type(values, dtype)
#    2738
#    2739     elif klass is DatetimeTZBlock and not is_datetime64tz_dtype(values.dtype):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    2694         # Need this first(ish) so that Sparse[datetime] is sparse
#    2695         cls = ExtensionBlock
# -> 2696     elif is_categorical_dtype(values.dtype):
#    2697         cls = CategoricalBlock
#    2698     elif issubclass(vtype, np.datetime64):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     561     if arr_or_dtype is None:
#     562         return False
# --> 563     return CategoricalDtype.is_dtype(arr_or_dtype)
#     564
#     565
#
# ~/.local/lib/python3.6/site-packages/pandas/core/dtypes/base.py in is_dtype(cls, dtype)
#     280         dtype = getattr(dtype, "dtype", dtype)
#     281
# --> 282         if isinstance(dtype, (ABCSeries, ABCIndexClass, ABCDataFrame, np.dtype)):
#     283             # https://github.com/pandas-dev/pandas/issues/22960
#     284             # avoid passing data to `construct_from_string`. This could
#
# ~/.local/lib/python3.6/site-packages/pandas/core/dtypes/generic.py in _check(cls, inst)
#      10     @classmethod  # type: ignore
#      11     def _check(cls, inst) -> bool:
# ---> 12         return getattr(inst, attr, "_typ") in comp
#      13
#      14     dct = dict(__instancecheck__=_check, __subclasscheck__=_check)
#
# KeyboardInterrupt:
